# %%
import requests
from bs4 import BeautifulSoup

# ニュース一覧ページのURL
url = "https://www.kiramex.com/news/"
#url = "https://news.yahoo.co.jp/"

# ページのHTMLを取得
response = requests.get(url)
response.encoding = response.apparent_encoding  # 文字コードを自動判別して設定

# HTMLをBeautifulSoupでパース
soup = BeautifulSoup(response.text, "html.parser")

# ニュース一覧の情報を抽出
news_list = soup.find_all("li", class_="news-block")

# ニュース情報の取得
for news in news_list:
    # ニュースの日付を取得
    date = news.find("p", class_="date").get_text(strip=True) if news.find("p", class_="date") else "N/A"
    
    # ニュースのタイトルを取得
    title = news.find("a", class_="title").get_text(strip=True)
    
    # ニュースのリンクを取得
    link = news.find("a", class_="title")["href"]

    print(f"Date: {date}")
    print(f"Title: {title}")
    print(f"Link: {link}")
    print("-" * 40)
# Out:
# Date: 2025年04月01日お知らせ
# Title: コーポレートサイトリニューアルお知らせ
# Link: https://www.kiramex.com/news-20250401/
# ----------------------------------------
# Date: 2025年02月06日メディア掲載
# Title: LiProにテックアカデミーが紹介されました
# Link: https://www.kiramex.com/news-20250206/
# ----------------------------------------
# Date: 2025年01月14日プレスリリース
# Title: リスキリングプログラム「LINEヤフーテックアカデミー」、2週間でChatGPTの基礎や使い方を学べる「はじめてのChatGPTコース」など4種の新コースを開設
# Link: https://www.kiramex.com/news-20250114/
# ----------------------------------------
# Date: 2024年12月01日お知らせ
# Title: 年末年始（2024年〜2025年）の休暇・営業に関するお知らせ
# Link: https://www.kiramex.com/news-20241201/
# ----------------------------------------
# Date: 2024年10月09日プレスリリース
# Title: キラメックスとLINEヤフー、山形県の産学官連携コンソーシアム「やまがたAI部」と、県内企業におけるAI人材育成に関する協定を締結
# Link: https://www.kiramex.com/news-20241009/
# ----------------------------------------
# Date: 2024年09月09日プレスリリース
# Title: テックアカデミー、学びに夢中になれる「イマーシブラーニング」を取り入れたコースの提供を開始　〜副業をスタートした受講者が3倍に増加した実証実験の実績〜
# Link: https://www.kiramex.com/news-20240909/
# ----------------------------------------
# Date: 2024年08月15日プレスリリース
# Title: LINEヤフーとキラメックス、香川県と連携し、県内における「女性デジタル人材」の育成を支援。本日より受講生を募集開始
# Link: https://www.kiramex.com/news-20240815/
# ----------------------------------------
# Date: 2024年06月18日プレスリリース
# Title: 50代のビジネスパーソンがリスキリング、オリジナルのアプリ開発で総務部門の定期タスクにかかる時間を87.5%削減
# Link: https://www.kiramex.com/news-20240618/
# ----------------------------------------
# Date: 2024年06月17日プレスリリース
# Title: キラメックスとネオス、生成AIの基礎理解から実務での活用までAI人材育成をワンストップ支援する研修プログラムを提供開始
# Link: https://www.kiramex.com/news-20240617/
# ----------------------------------------
# Date: 2024年06月06日メディア掲載
# Title: TECH+にLINEヤフーテックアカデミーの新コース開設に関する記事が掲載されました
# Link: https://www.kiramex.com/tech%e3%81%abline%e3%83%a4%e3%83%95%e3%83%bc%e3%83%86%e3%83%83%e3%82%af%e3%82%a2%e3%82%ab%e3%83%87%e3%83%9f%e3%83%bc%e3%81%ae%e6%96%b0%e3%82%b3%e3%83%bc%e3%82%b9%e9%96%8b%e8%a8%ad%e3%81%ab%e9%96%a2/
# ----------------------------------------

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
# ニュース一覧ページのURL
# url = "https://www.kiramex.com/news/"
url = "https://www.lycorp.co.jp/ja/news/"

# ページのHTMLを取得
response = requests.get(url)
response.encoding = response.apparent_encoding  # 文字コードを自動判別して設定

# HTMLをBeautifulSoupでパースし、body部分を取り出す
soup = BeautifulSoup(response.text, "html.parser")
body_html = str(soup.body)  # body部分のHTMLを文字列として取得
print(body_html) # 結果を表示して確認
# Out:
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NJPSPSD5" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script src="/ja/ja_header.js"></script>
# <div class="global-container">
# <div class="breadcrumbs">
# <ul>
# <li><a href="/ja/"><img alt="トップページ" height="14" src="/assets/images/icon_home.svg" width="14"/></a></li>
# <li>ニュース</li>
# </ul>
# </div>
# <div class="page-heading-lv2">
# <div class="inner">
# <h1>ニュース</h1>
# <p>News</p>
# </div>
# <picture>
# <source media="(max-width: 767px)" srcset="/assets/images/news/sp/LY_siteKV_news.jpg"/>
# <img alt="" src="/assets/images/news/LY_siteKV_news.jpg"/>
# </picture>
# </div>
# <div class="body-container no-top-padding">
# <div class="body-inner search-target">
# <div class="c-search-header" id="news-search">
# <h2 id="press-release">プレスリリース</h2>
# <button class="c-search-open" type="button">絞り込み検索</button>
# </div>
# <ul class="c-col-set-3 c-viewmore-list" id="js-result">
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017729/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-05-15">2025年5月15日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>PayPay銀行、すべての個人のお客さまが「LINE連携サービス」を利用可能に</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017726/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/4fb6cd7836cb50ce470c43aac208ef402475df68.png"/>
# <div class="txt">
# <time datetime="2025-05-14">2025年5月14日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!クイックマート、専用アプリの提供を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017646/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/7036429dd509570b4af882a835571fe083153405.jpg"/>
# <div class="txt">
# <time datetime="2025-05-08">2025年5月8日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!トラベル、人気宿泊施設の航空券付きプランがお得になる大型セール企画「ヤフーパック ウルトラセール」を5月8日から開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017598/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/bcf354932597617f66a9a8b4be9b3528d9e241b0.png"/>
# <div class="txt">
# <time datetime="2025-05-01">2025年5月1日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、食品や日用品がおトクな生活応援セール  「ヤフービッグボーナス」を本日より開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017587/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/MAIN_KV.png"/>
# <div class="txt">
# <time datetime="2025-04-30">2025年4月30日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEスタンプメーカー、アプリ内画像からシームレスにLINEスタンプを作成する機能の提供を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017538/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/55555a8e27a32e6ee4b125c7f5182c799aa05f3f.jpg"/>
# <div class="txt">
# <time datetime="2025-04-25">2025年4月25日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!検索、宿泊施設のクチコミを生成AIが要約し、検索結果上に表示する機能を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017527/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/e2521d77d2022888ae5cc59ee81b721b72d6a98b.png"/>
# <div class="txt">
# <time datetime="2025-04-24">2025年4月24日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEヤフーとブリューアス、昨年に続き香川県と連携し、県内におけるデータ・AI人材の育成を支援</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017525/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/b1233a86fb4058bfa36b2dbd6fd4563827153e60.jpg"/>
# <div class="txt">
# <time datetime="2025-04-24">2025年4月24日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!検索、生成AIを活用して都道府県別のおすすめ料理や名物などのグルメ情報を表示する機能を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017522/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/1e24f7447f2858aa64b89edc10bef3a13942be98.png"/>
# <div class="txt">
# <time datetime="2025-04-23">2025年4月23日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ニュース、生成AIが多数の記事から 「いま話題になっている重要ニュース」を選定する「AIトピ」の提供を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017491/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/20270422_pphs_heatstroke_kv.png"/>
# <div class="txt">
# <time datetime="2025-04-22">2025年4月22日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>PayPayほけん、PayPayから加入できる熱中症リスクに備える保険 「熱中症お見舞い金」を2025年も提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017492/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/Yahoo%21Carnavi_image01.jpg"/>
# <div class="txt">
# <time datetime="2025-04-22">2025年4月22日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!カーナビ、「推しドラ」機能に竹達彩奈さんが登場 オリジナル音声案内でドライブ体験をさらに楽しく</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017387/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/edf4129c746a1cec7f770079aca1350783861c85.jpg"/>
# <div class="txt">
# <time datetime="2025-04-21">2025年4月21日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>みんカラ、「みんカラ サーキットラップタイム」の提供を開始 サーキットごとのラップタイムをランキング形式で確認可能に</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017412/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/84125e5504c1236d2d5efea7b4fa04b7662c8f49.png"/>
# <div class="txt">
# <time datetime="2025-04-18">2025年4月18日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「LINE占い」、12周年を記念した特別企画を開催！ 無料のタロット占いや人気占い師50％OFFセールなど 5つの特別企画で感謝を伝える3週間</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017408/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/cd3a393913c65ba9bc91adcd1f5f5b748c6ac750.jpg"/>
# <div class="txt">
# <time datetime="2025-04-17">2025年4月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!検索、検索結果上で条件を指定して宿泊施設の料金比較ができる機能の提供を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017395/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/7ec5528baf69913d887cd05af09416880a05459c.png"/>
# <div class="txt">
# <time datetime="2025-04-15">2025年4月15日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>生成AIを活用した新サービスが「LINE」に誕生。「LINE AI」、「LINE AIトークサジェスト」を提供開始。「LINE」が人とAIをつなぐプラットフォームへ</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017388/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/a1f004b7e88d9a53b72dea28b24c3132e14326a8.png"/>
# <div class="txt">
# <time datetime="2025-04-15">2025年4月15日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>“選考直結型“夏季インターンシップの募集を開始 生成AIを用いたプロダクト開発など5職種100以上のポジションから約230名を募集</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017396/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/c29bb75ea4c4777c2b4f870b6f60764603da984f.png"/>
# <div class="txt">
# <time datetime="2025-04-15">2025年4月15日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>“スマホですべて完結”する「Yahoo!ふるさと納税」、昨年12月の提供開始以降、利用者数は順調に伸長</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017335/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/b371b1e2ba4abc9c312930232551788c336a1069.png"/>
# <div class="txt">
# <time datetime="2025-04-14">2025年4月14日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>PayPayによるPayPay銀行の株式取得（子会社化）の完了に関するお知らせ</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017297/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/435ec6bb813b680b6ce946f179ce4d9c937e61ce.png"/>
# <div class="txt">
# <time datetime="2025-04-09">2025年4月9日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!フリマ、「ゴールド出品者プログラム」の提供を開始。配達完了から最短24時間後に入金申請が可能となり、受取連絡を待たないスムーズな取引を実現</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017280/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/2025_spring_SONG-LPS%402x.png"/>
# <div class="txt">
# <time datetime="2025-04-09">2025年4月9日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>“春”と言えばこの曲！LINE MUSICが世代別に聞いた、2025年度版「春ソングランキングTOP10」を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017275/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/jp/common/2025/250408_YJ_AIchat_kv%20%282%29.png"/>
# <div class="txt">
# <time datetime="2025-04-08">2025年4月8日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo! JAPANアプリ、質問するとチャット形式で情報を深掘りしてくれる、「AIアシスタント機能」を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017244/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/7f33536b8841645f52c087e669ec74eb4ad18005.png"/>
# <div class="txt">
# <time datetime="2025-04-02">2025年4月2日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEギフト、サービス開始10周年を記念して「LINEギフトアワード」を初開催 10周年インフォグラフィックスの公開や、特別なキャンペーンも開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017241/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/359a901e26b666fbcec0ca270e2be0dee40ea65f.png"/>
# <div class="txt">
# <time datetime="2025-04-02">2025年4月2日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、3月に開催した「Yahoo!ショッピング 超PayPay祭」の売れ筋商品などの結果を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017240/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/49eecfa768e3628190beb90002471c420c60182e.jpg"/>
# <div class="txt">
# <time datetime="2025-04-01">2025年4月1日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEヤフー、新たな法人向けサービス「LINEプロモーション絵文字」の正式提供を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017247/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/9acdcc7a307162a415fd85b3bb0166881a20052f.png"/>
# <div class="txt">
# <time datetime="2025-04-01">2025年4月1日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「LINE Pay 公的個人認証サービス」「LINE 公的個人認証サービス（JPKI）」に名称変更</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017239/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-03-31">2025年3月31日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ネット募金、ミャンマー地震緊急支援募金の特設ページを開設</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017188/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/chiipoke_press_mv.png"/>
# <div class="txt">
# <time datetime="2025-03-27">2025年3月27日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>『ちいかわぽけっと』リリース記念特集をYahoo! JAPANで開催　第一弾は、検索結果上に、「ちいかわ」たちが舞うお祝い演出と「ちいぽけ遊び方診断」が登場</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017049/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/KV.png"/>
# <div class="txt">
# <time datetime="2025-03-25">2025年3月25日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「LINE」のトークルームで送受信したリンク先で「Yahoo!検索」が利用可能に／当社サービス間の連携を強化し、ユーザー体験を向上</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017168/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/1e69f567bd210e5d0fb4e8ac6a10b22de82c6216.png"/>
# <div class="txt">
# <time datetime="2025-03-24">2025年3月24日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!フリマ、生成AIが商品画像から、商品情報の作成をサポートする機能「らくらくAI出品」を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017161/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/53458c07ec15dd409e0ea549d4a0cad4a75b3a60.jpg"/>
# <div class="txt">
# <time datetime="2025-03-21">2025年3月21日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!トラベル、人気宿泊施設の航空券付きプランがお得になる 大型セール企画「ヤフーパック ウルトラセール」を3月24日から開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017142/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/6d8f349fa1bcc84c4b35ead1f509aaab90a3ba3f.png"/>
# <div class="txt">
# <time datetime="2025-03-21">2025年3月21日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、「安全・安心への取り組みレポート」を公開</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017166/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/LINE%20CONFERENCE%20THAILAND%202025%20.jpeg"/>
# <div class="txt">
# <time datetime="2025-03-21">2025年3月21日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINE Thailand、「LINE CONFERENCE THAILAND 2025」を開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017165/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/jp/common/6fef0f0c4b56b9c9f37779c859f173ad898d1a51.png"/>
# <div class="txt">
# <time datetime="2025-03-19">2025年3月19日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、生成AIを活用した、おトクな日を提案する機能導入後の成果を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017160/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/TOP.jpg"/>
# <div class="txt">
# <time datetime="2025-03-19">2025年3月19日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>ビジネス用クリエイティブツール「LINE Creative Lab」、生成AIによる画像生成機能を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017128/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/aee506b58ee4e5281ac5d1f5ceec66dcc9612d99.png"/>
# <div class="txt">
# <time datetime="2025-03-18">2025年3月18日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEヤフー、闇バイト対策として新たな取り組みを開始／闇バイトへの加担リスクを学べる中学生・高校生向け 情報モラル教材を静岡大学と共同開発／さらに「LINE」を悪用した闇バイト・詐欺行為の撲滅を目指し、啓発活動を実施</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017110/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/20250317_ls_fx5th_kv.png"/>
# <div class="txt">
# <time datetime="2025-03-17">2025年3月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINE証券、「LINE FX」提供開始から5周年を迎え、通貨ペア・ラージ銘柄の追加と記念キャンペーンを開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017111/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/62f05d68297b09ca2c1af614769ae340a3a84062.png"/>
# <div class="txt">
# <time datetime="2025-03-14">2025年3月14日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「3.11 検索は、チカラになる。」に合計約1050万人が参加 3.11企画を通じて総額約5837万円を東日本大震災および能登半島地震・豪雨の被災地支援に取り組む団体へ寄付</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017082/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-03-10">2025年3月10日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「健康経営優良法人2025（ホワイト500）」に9年連続で認定</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017079/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/PressRelease_LVCC2025_result.png"/>
# <div class="txt">
# <time datetime="2025-03-10">2025年3月10日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINE VOOMで最も活躍したクリエイターを表彰する「LINE VOOM Creator Contest 2025」受賞者を決定</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017076/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/beststoreawad_KV.png"/>
# <div class="txt">
# <time datetime="2025-03-10">2025年3月10日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、「ベストストアアワード2024」にてLYPプレミアム会員施策などが奏功し、取扱高が前年を上回る成長と発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017070/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/main.png"/>
# <div class="txt">
# <time datetime="2025-03-07">2025年3月7日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEスキマニ 生成AIを活用した求人作成のサポート機能を導入 2ステップで見出しと業務内容の生成が可能</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017071/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/9bd4ebd8d62592066f717bcbacdae05185eb6d55.png"/>
# <div class="txt">
# <time datetime="2025-03-07">2025年3月7日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!オークション、「ベストストアアワード2024」を開催し、年間ベストストア53店舗を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017063/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-03-06">2025年3月6日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>スポーツ庁主催「第４回Sport in Lifeアワード優秀賞」を受賞</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017048/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2025/ddd50c0d63c4051c42a5323d633436756be51f2d.jpg"/>
# <div class="txt">
# <time datetime="2025-03-05">2025年3月5日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>スポーツナビ「センバツLIVE!」、春の甲子園を今年も全試合無料ライブ配信</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/017044/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023
">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/db08737c470932454950da959343be8bf5ac53b0.png"/>
# <div class="txt">
# <time datetime="2025-02-20">2025年2月20日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>2月22日は「猫の日」。LINEスタンプの制作や購入が猫の保護・支援につながる特別企画を開催</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016976/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/0ad3f5a809db7b702dd396d530d6205dd468136f.png"/>
# <div class="txt">
# <time datetime="2025-02-20">2025年2月20日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、生成AIを活用して、ポイントがより多く付与されるおトクな購入日を提案する機能のβ版を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016959/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/img1.png"/>
# <div class="txt">
# <time datetime="2025-02-17">2025年2月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEバイト、10周年を迎えたことを記念して特設サイトを開設　「お祝いイラスト」や「10年のあゆみ」など特別コンテンツを公開</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016957/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/20250217_lineschool_image01.png"/>
# <div class="txt">
# <time datetime="2025-02-17">2025年2月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEヤフー、全国の小中学校教員・保護者を対象に 「学校と保護者の連絡に関する実態調査」を実施</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016956/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/3add98706dd1c1b7dede7e960b95a6f3817ab384.png"/>
# <div class="txt">
# <time datetime="2025-02-17">2025年2月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>ひろゆきさんの切り抜き画像を使ったLINEスタンプの制作・販売が可能に キャラではなく人物との初コラボ、スタンプアレンジ機能にも初対応</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016958/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/matsuri.png"/>
# <div class="txt">
# <time datetime="2025-02-17">2025年2月17日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「超PayPay祭」が3月1日からスタート！</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016950/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/PlessRelease_buzzaward2024w_result.png"/>
# <div class="txt">
# <time datetime="2025-02-14">2025年2月14日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>3か月にわたり最もユーザーから“推された”動画がいよいよ決定！ 「LINE VOOM バズった動画大賞 2024 冬」受賞動画を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016952/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-02-13">2025年2月13日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>S&amp;Pグローバル社「The Sustainability Yearbook 2025」において「The Sustainability Yearbook Member」に5年連続で選定</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016951/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/commentprr250213_main.jpg"/>
# <div class="txt">
# <time datetime="2025-02-13">2025年2月13日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ニュース、投稿内容の表現の見直しを提案するAI「コメント添削モデル」導入後の効果を発表</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016944/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/jp/common/4b3447eca30ff932230960f75d29f43c4b314ed5.png"/>
# <div class="txt">
# <time datetime="2025-02-12">2025年2月12日</time>
# <span class="category" data-slug="corporate">マーケティングソリューション</span>
# <p>学校と保護者の連絡サービス「LINEスクール 連絡帳」、 内田洋行の学習eポータル「L-Gate」との機能連携を開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016933/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/KV.png"/>
# <div class="txt">
# <time datetime="2025-02-10">2025年2月10日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEみらい財団と常葉大学、“SNSの誹謗中傷リスク”が学べる 中高生向け情報モラル教材を共同開発</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016934/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-02-10">2025年2月10日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>PayPayによるPayPay証券の株式取得および第三者割当増資引受について</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016929/">
# <img alt="" src="/assets/images/ogp_ly_jp_bk_1200_628.png"/>
# <div class="txt">
# <time datetime="2025-02-07">2025年2月7日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>CDPの気候変動分野で最高評価となる「Aリスト」に初選定</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016930/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/cc17289d0559c36eb1e7201c211a8e3672fd1465.png"/>
# <div class="txt">
# <time datetime="2025-02-07">2025年2月7日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>情報空間の健全性確保のための取り組みについて、特設サイトを公開</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016918/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/93b49c5aabc7aceb647395dcb694ff08bd2bced1.jpg"/>
# <div class="txt">
# <time datetime="2025-02-05">2025年2月5日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>スポーツナビ、カーリング日本選手権の「一投速報」を初提供、一投ごとにストーンの配置図をリアルタイムで掲載</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016900/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/image%20%2832%29.png"/>
# <div class="txt">
# <time datetime="2025-02-05">2025年2月5日</time>
# <span class="category" data-slug="corporate">メディア</span>
# <p>Yahoo!天気アプリ、「雨雲レーダー」画面上に「みんなの投稿」モードをAndroid版より提供開始　「もうすぐ降りそう」などリアルタイムの天気に関するユーザー投稿をレーダー上ですぐ確認できる</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016909/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/2025_linemusic_Valentine_SONG-LPS%402x.png"/>
# <div class="txt">
# <time datetime="2025-02-04">2025年2月4日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>もうすぐバレンタイン！LINE MUSICが世代別に聞いた「片思いの時に聴きたくなる曲ランキングTOP10」を発表！</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016904/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/20250203_lineresearch_main.png"/>
# <div class="txt">
# <time datetime="2025-02-03">2025年2月3日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>【LINEリサーチ】若年層の流行に関する定点調査（2024年12月）</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016902/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/a2a7393fe007843fabfb8a580b08e91c2bdb4f6c.png"/>
# <div class="txt">
# <time datetime="2025-02-03">2025年2月3日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、手軽に行える節電対策や省エネにつながる最新家電商品を紹介する「省エネルギー特集」を公開</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016896/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/20250203_top_image01.png"/>
# <div class="txt">
# <time datetime="2025-02-03">2025年2月3日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>「ムーミン」80周年を記念して、「スナフキン」がきせかえに仲間入り！ムーミングッズが当たる「毎日スロットくじ」など、スペシャルコンテンツがYahoo! JAPANに登場！</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016871/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/f3ab09c71133faa6e182ae044a8419bcb3c84ceb.png"/>
# <div class="txt">
# <time datetime="2025-01-30">2025年1月30日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>LINEオープンチャットを活用した地域活性化の新たな試み。奈良の新名物を目指す「もっちのうまっちぃオイル漬け」の発売が決定</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016893/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/jp/common/20250130_msc_image01.png"/>
# <div class="txt">
# <time datetime="2025-01-30">2025年1月30日</time>
# <span class="category" data-slug="corporate">マーケティングソリューション</span>
# <p>学校向け総合ソリューション「LINEスクール」、 第一弾として、無料から使える学校と保護者の連絡サービス「LINEスクール 連絡帳」を提供開始</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016894/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/2023/3420b3c680cc3dc54a1c208105bb71666c1d6c54.png"/>
# <div class="txt">
# <time datetime="2025-01-30">2025年1月30日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ショッピング、住所を知らない相手にもギフトを贈ることができる「ソーシャルギフト機能」で贈り物をすると10回に1回の確率で支払い額全額戻ってくるキャンペーンを実施</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016859/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news/ja/common/pr/2025/f991a1a4dd767456417ad4670038fe6c8ea95311.jpg"/>
# <div class="txt">
# <time datetime="2025-01-29">2025年1月29日</time>
# <span class="category" data-slug="corporate">プレスリリース</span>
# <p>Yahoo!ニュース、「ベスト エキスパート 2025」授賞式開催決定！安藤優子氏やスザンヌ氏など選考委員が初参加、特設ページでノミネート一覧を公開</p>
# </div>
# </a>
# </li>
# <li class="c-col">
# <a class="c-article-panel-d2" href="https://www.lycorp.co.jp/ja/news/release/016886/">
# <img alt="" src="https://www.lycorp.co.jp/ja/news
# <p>役員報酬の一部自主返上に関するお知らせ</p>
# </a>
# </li>
# <li class="c-col">
# <a href="https://www.lycorp.co.jp/ja/news/announcements/007778/">
# <time datetime="2024-03-05">2024年3月5日</time>
# <span class="category">お知らせ</span>
# <p>当社に対する総務省からの行政指導について</p>
# </a>
# </li>
# <li class="c-col">
# <a href="https://www.lycorp.co.jp/ja/news/announcements/007710/">
# <time datetime="2024-02-14">2024年2月14日</time>
# <span class="category">お知らせ</span>
# <p>不正アクセスによる個人情報漏えいへの再発防止策に関するお知らせ</p>
# </a>
# </li>
# <li class="c-col">
# <a href="https://www.lycorp.co.jp/ja/news/announcements/007711/">
# <time datetime="2024-02-14">2024年2月14日</time>
# <span class="category">お知らせ</span>
# <p>委託先2社のアカウントを利用した不正アクセスによる、従業者等の情報漏えいに関するお知らせとお詫び</p>
# </a>
# </li>
# <li class="c-col">
# <a href="https://www.lycorp.co.jp/ja/news/announcements/001262/">
# <time datetime="2024-02-01">2024年2月1日</time>
# <span class="category">お知らせ</span>
# <p>2024年4月1日付の当社役員人事に関するお知らせ</p>
# </a>
# </li>
# <li class="c-col">
# <a href="https://www.lycorp.co.jp/ja/news/announcements/007712/">
# <time datetime="2023-11-27">2023年11月27日</time>
# <span class="category">お知らせ</span>
# <p>不正アクセスによる、情報漏えいに関するお知らせとお詫び（2024/2/14更新）</p>
# </a>
# </li>
# </ul>
# <button class="c-viewmore-button" data-num="5" type="button"><span>もっと見る</span></button>
# <h2 class="c-heading" id="notice">プライバシー＆セキュリティのお知らせ</h2>
# <ul class="c-article-list-topics mt40 sp-mt40 ps-list-topics">
# </ul>
# <div class="center mt40 sp-mt40" style="margin-bottom: 120px;">
# <a class="c-button" href="/ja/privacy-security/announcement/">一覧を見る</a>
# </div>
# </div><!-- /.body-inner -->
# </div><!-- /.body-container -->
# <div class="body-container bg-gray">
# <div class="body-inner">
# <h2 class="c-heading" id="past-press-release">Global News</h2>
# <ul class="c-col-set-3 mt60 sp-mt40">
# <li class="c-col">
# <a class="c-link-panel-text line" href="https://linecorp.com/en/pr/news/global/" target="_blank">LINEグローバルサイトを見る</a>
# </li>
# </ul>
# <h2 class="c-heading mt80 sp-mt56" id="past-press-release">合併前のプレスリリース</h2>
# <ul class="c-col-set-3 mt60 sp-mt40">
# <li class="c-col">
# <a class="c-link-panel-text line" href="https://www.lycorp.co.jp/ja/news/archive/L/">旧LINE株式会社の<br/>プレスリリースを見る</a>
# </li>
# <li class="c-col">
# <a class="c-link-panel-text yahoo" href="https://www.lycorp.co.jp/ja/news/archive/Y/">旧ヤフー株式会社の<br/>プレスリリースを見る</a>
# </li>
# <li class="c-col">
# <a class="c-link-panel-text" href="https://www.lycorp.co.jp/ja/news/archive/Z/">旧Zホールディングス<br/>株式会社のプレスリリースを見る</a>
# </li>
# </ul>
# </div><!-- /.body-inner -->
# </div><!-- /.body-container -->
# <script src="/ja/ja_footer.js"></script>
# </div><!-- /.global-container -->
# <a class="page-top" href="#top">Page top</a>
# <a class="page-top" href="#top">Page top</a>
# <div class="search-modal">
# <div class="inner">
# <div class="head">
# <p>絞り込み検索</p>
# <button class="btn-reset" type="button">選択を解除</button>
# </div>
# <div class="scroll">
# <dl>
# <dt>年を選択</dt>
# <dd>
# <ul id="js-year">
# <li><input checked="" id="year-2025" name="year" type="radio" value="2025"/><label for="year-2025">2025年</label></li>
# <li><input id="year-2024" name="year" type="radio" value="2024"/><label for="year-2024">2024年</label></li>
# <li><input id="year-2023" name="year" type="radio" value="2023"/><label for="year-2023">2023年</label></li>
# </ul>
# </dd>
# <dt>カテゴリを選択</dt>
# <dd>
# <ul id="js-category">
# <li><input checked="" id="category-0" name="category" type="radio" value="all"/><label for="category-0">すべて</label></li>
# <li><input data-c2023="9" data-c2024="39" data-c2025="20" data-category="コーポレート" id="category-1" name="category" type="radio" value="corporate"/><label for="category-1">コーポレート</label></li>
#
# <li><input data-c2023="1" data-c2024="10" data-c2025="4" data-category="検索" id="category-2" name="category" type="radio" value="search"/><label for="category-2">検索</label></li>
#
# <li><input data-c2023="15" data-c2024="58" data-c2025="24" data-category="コマース" id="category-3" name="category" type="radio" value="commerce"/><label for="category-3">コマース</label></li>
#
# <li><input data-c2023="0" data-c2024="8" data-c2025="1" data-category="ローカル" id="category-4" name="category" type="radio" value="local"/><label for="category-4">ローカル</label></li>
#
# <li><input data-c2023="19" data-c2024="29" data-c2025="12" data-category="メディア" id="category-5" name="category" type="radio" value="media"/><label for="category-5">メディア</label></li>
#
# <li><input data-c2023="0" data-c2024="22" data-c2025="4" data-category="LINEアプリ" id="category-6" name="category" type="radio" value="lineapp"/><label for="category-6">LINEアプリ</label></li>
#
# <li><input data-c2023="6" data-c2024="9" data-c2025="6" data-category="Fintech" id="category-7" name="category" type="radio" value="fintech"/><label for="category-7">Fintech</label></li>
#
# <li><input data-c2023="4" data-c2024="22" data-c2025="10" data-category="マーケティングソリューション" id="category-8" name="category" type="radio" value="ms"/><label for="category-8">マーケティングソリューション</label></li>
#
# <li><input data-c2023="0" data-c2024="1" data-c2025="1" data-category="Global" id="category-9" name="category" type="radio" value="global"/><label for="category-9">Global</label></li>
#
# <li><input data-c2023="2" data-c2024="2" data-c2025="0" data-category="Web3" id="category-10" name="category" type="radio" value="web3"/><label for="category-10">Web3</label></li>
#
# <li><input data-c2023="12" data-c2024="45" data-c2025="11" data-category="エンタメ" id="category-11" name="category" type="radio" value="entertainment"/><label for="category-11">エンタメ</label></li>
#
# <li><input data-c2023="1" data-c2024="4" data-c2025="1" data-category="技術" id="category-12" name="category" type="radio" value="tech"/><label for="category-12">技術</label></li>
#
# <li><input data-c2023="0" data-c2024="0" data-c2025="0" data-category="プライバシー＆セキュリティ" id="category-13" name="category" type="radio" value="security"/><label for="category-13">プライバシー＆セキュリティ</label></li>
#
# <li><input data-c2023="3" data-c2024="14" data-c2025="1" data-category="その他" id="category-14" name="category" type="radio" value="others"/><label for="category-14">その他</label></li>
#
# </ul>
# </dd>
# </dl>
# </div>
# <div class="button">
# <button class="btn-close" type="button">閉じる</button>
# <button class="btn-reset" type="button">選択を解除</button>
# <button class="btn-submit" id="btn-submit" type="button">絞り込む</button>
# </div>
# <button class="btn-close-pc" type="button">閉じる</button>
# </div><!-- /.inner -->
# </div><!-- /.search-modal -->
# <div class="bg-search-modal"></div>
# <script>
# (function(){
#   sessionStorage.setItem("news_listpage", "https://www.lycorp.co.jp/ja/news/");
# })();
# </script>
# <script>
# (function(){
# var main_func = function(topics_paths, containers, categorys, max, all_json_data, replace_paths) {
#     var topics_path = topics_paths.shift();
#     var category = categorys.shift();
#     let container = containers[0];
#
#     if(topics_path.match(/.json$/)) {
#       $.getJSON(topics_path)
#       .done(function(json){ // jsonの読み込みに成功した時
#         for(var i = 0; json[i] && (i<max); i++){ /* 配列要素がないか、取得最大数を超えていれば処理を抜ける */
#           if(!(category=='*')){
#             json[i].tags = [category];
#           }
#           // json[i].dateを「yyyy-mm-dd」形式に変換
#           json[i].date = json[i].date.replaceAll('.', '-');
#           all_json_data.push(json[i]);
#         }
#         if (topics_paths.length) {
#           main_func(topics_paths, containers, categorys, max, all_json_data, replace_paths);
#         } else {
#           // dateを降順にソートする
#           let sort_result = all_json_data.sort(function(a, b) {
#             return (a.date > b.date) ? -1 : 1;
#           });
#           // console.log(sort_result);
#
#
#           for(var i = 0; (sort_result[i] && i<(max)); i++){ /* 配列要素がないか、取得最大数*2（ソート後は固定値で5,6件かも）を超えていれば処理を抜ける */
#             // sort_result[i].dateを日本語に変換
#             var sort_result_dates = sort_result[i].date.split("-");
#             var sort_result_month = (sort_result_dates[1][0] == '0') ? sort_result_dates[1].substring(1,2) : sort_result_dates[1];
#             var sort_result_day = (sort_result_dates[2][0] == '0') ? sort_result_dates[2].substring(1,2) : sort_result_dates[2];
#             sort_result[i].jp_date = sort_result_dates[0] + '年' + sort_result_month + '月' + sort_result_day + '日';
#
#             var json_data = sort_result[i];
#             var topic_category = sort_result[i].tags[0];
#
#
#             var tags = "<li class=\"c-col\">\n"
# 		 + "<a href=\"" +  json_data.url  + "\" target=\"" +  ( (json_data.on_info_link-0)?'_blank':'_self' )  + "\">\n"
# 		 + "<time datetime=\"" +  json_data.date  + "\">" +  json_data.jp_date  + "</time>\n"
# 		 + "<span class=\"category\">" +  json_data.tags.join(',')  + "</span>\n"
# 		 + "<p>" +  json_data.title  + "</p>\n"
# 		 + "</a>\n"
# 		 + "</li>\n";
#             $("." + container).append(tags);
#           }
#         }
#       })
#       .fail(function(){
#         console.log('init失敗_json: '+category);
#       })
#     } else if(topics_path.match(/^.*\/ir\/.*$/)) {
#       $.ajax({
#         url: topics_path,
#         cache: false,
#         dataType:"xml"
#       })
#       .done(function(rss){ // rssの読み込みに成功した時
#         $(rss).find('item').each(function(){
#           var rss_title = $(this).find('title').text();
#           var rss_link = $(this).find('link').text();
#           var rss_date = $(this).find('dc\\:date').text();
#           // console.log('rss_date: '+rss_date);
#           // rss_dateを「yyyy-mm-dd」形式に変換
#           var rss_dates = rss_date.split("-");
#           var rss_date_month = rss_dates[1];
#           var rss_date_day = rss_dates[2].substring(0,2);
#           rss_date = rss_dates[0] + '-' + rss_date_month + '-' + rss_date_day;
#
#           all_json_data[all_json_data.length] = {"title": rss_title, "url": rss_link, "date": rss_date, "pr_or_notice": "", "tags":[category]};
#         });
#         if (topics_paths.length) {
#           main_func(topics_paths, containers, categorys, max, all_json_data, replace_paths);
#         } else {
#           // dateを降順にソートする
#           let sort_result = all_json_data.sort(function(a, b) {
#             return (a.date > b.date) ? -1 : 1;
#           });
#           // console.log(sort_result);
#           for(var i = 0; (sort_result[i] && i<(max)); i++){ /* 配列要素がないか、取得最大数*2（ソート後は固定値で5,6件かも）を超えていれば処理を抜ける */
#             // sort_result[i].dateを日本語に変換
#             var sort_result_dates = sort_result[i].date.split("-");
#             var sort_result_month = (sort_result_dates[1][0] == '0') ? sort_result_dates[1].substring(1,2) : sort_result_dates[1];
#             var sort_result_day = (sort_result_dates[2][0] == '0') ? sort_result_dates[2].substring(1,2) : sort_result_dates[2];
#             sort_result[i].jp_date = sort_result_dates[0] + '年' + sort_result_month + '月' + sort_result_day + '日';
#
#             var json_data = sort_result[i];
#             var topic_category = sort_result[i].tags[0];
#             if( replace_paths ){
#               json_data.url = json_data.url.replace(replace_paths[0],replace_paths[1]);
#             }
#
#
#             var tags = "<li class=\"c-col\">\n"
# 		 + "<a href=\"" +  json_data.url  + "\" target=\"" +  ( (json_data.on_info_link-0)?'_blank':'_self' )  + "\">\n"
# 		 + "<time datetime=\"" +  json_data.date  + "\">" +  json_data.jp_date  + "</time>\n"
# 		 + "<span class=\"category\">" +  json_data.tags.join(',')  + "</span>\n"
# 		 + "<p>" +  json_data.title  + "</p>\n"
# 		 + "</a>\n"
# 		 + "</li>\n";
#             $("." + container).append(tags);
#           }
#         }
#       })
#       .fail(function(){
#         console.log('init失敗_rss: '+category);
#       })
#     } else {
#       console.log('init失敗');
#     }
#   }
#
#
# window.addEventListener('DOMContentLoaded', function(){
#   var topics_paths="ja/privacy-security/list.json".split(",");
#   var containers="ps-list-topics".split(",");
#   var categorys="*".split(",");
#   var max=3;
#   var replace_paths="".split(",");
#   if( replace_paths.length < 2){
#     replace_paths = null;
#   }
#   var all_json_data = [];
#   for(var i = 0; i<topics_paths.length; i++) {
#     if(!topics_paths[i].match(/https?:\/\//)) {
#       topics_paths[i] = "https://www.lycorp.co.jp/" + topics_paths[i].replace(/^\//,'');
#     }
#   }
#
#   main_func(topics_paths, containers, categorys, max, all_json_data, replace_paths);
#
# });
#
# })();
# </script>
# <script src="/assets/js/lib.js"></script>
# <script src="/assets/js/common.js"></script>
# <script>
# $(function() {
#     var json_path = '/ja/story/list.json';
#     var container = 'js-cblog-result';
#     var label = 'コーポレートブログ';
#     var max = '3';
#
#     $.getJSON(json_path)
#       .done(function(json){ // jsonの読み込みに成功した時
#       for(var i = 0; (i < max) && (i<json.length); i++ ){
#           var element = json[i];
#
#
#
#           var tags= "<li class=\"c-col is-shown\">\n"
# 		 + "<a href=\"" +  element.url  + "\" class=\"c-article-panel-d2\">\n"
# 		 + "<img src=\"" +  element.img  + "\" alt=\"\">\n"
# 		 + "<div class=\"txt\">\n"
# 		 + "<time datetime=\"" +  element.date.replaceAll('.','-')  + "\">" +  element.date.replace(/\.0?/,'年').replace(/\.0?/,'月')  + "日</time>\n"
# 		 + "<span class=\"category\" data-slug=\"corporate\">" +  ((element.tags[0])?(element.tags[0]):'')  + "</span>\n"
# 		 + "<p>" +  element.title  + "</p>\n"
# 		 + "</div>\n"
# 		 + "</a>\n"
# 		 + "</li>\n";
#
#           $("#" + container).append(tags);
#         }
#       })
#       .fail(function(){
#         console.log('init失敗');
#       })
#       .always(function(){
#
#       });
#
# });
# </script>
# </body>

# %%
# LLMにニュース一覧を抽出させるプロンプトを作成
prompt = f"""
以下のHTMLから最新のニュースを抽出し、「日付、タイトル、リンク」の形式で一覧を出力してください。一覧以外は出力しないでください。

# 出力様式：
Date: 日付
Title: タイトル
Link: リンク
--------------------

#HTML:
{body_html[:5000]}
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": prompt},
    ],
    max_tokens=500,
    temperature=0.3
)

# LLMからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# ```
# Date: 2025年5月15日
# Title: PayPay銀行、すべての個人のお客さまが「LINE連携サービス」を利用可能に
# Link: https://www.lycorp.co.jp/ja/news/release/017729/
# --------------------
# Date: 2025年5月14日
# Title: Yahoo!クイックマート、専用アプリの提供を開始
# Link: https://www.lycorp.co.jp/ja/news/release/017726/
# --------------------
# Date: 2025年5月8日
# Title: Yahoo!トラベル、人気宿泊施設の航空券付きプランがお得になる大型セール企画「ヤフーパック ウルトラセール」を5月8日から開催
# Link: https://www.lycorp.co.jp/ja/news/release/017646/
# --------------------
# Date: 2025年5月1日
# Title: Yahoo!ショッピング、食品や日用品がおトクな生活応援セール  「ヤフービッグボーナス」を本日より開催
# Link: https://www.lycorp.co.jp/ja/news/release/017598/
# --------------------
# Date: 2025年4月30日
# Title: LINEスタンプメーカー、アプリ内画像からシームレスにLINEスタンプを作成する機能の提供を開始
# Link: https://www.lycorp.co.jp/ja/news/release/017587/
# --------------------
# Date: 2025年4月25日
# Title: Yahoo!検索、宿泊施設のクチコミを生成AIが要約し、検索結果上に表示する機能を提供開始
# Link: https://www.lycorp.co.jp/ja/news/release/017538/
# --------------------
# Date: 2025年4月24日
# Title: LINEヤフーとブリューアス、昨年に続き香川県と連携し、県内におけるデータ・AI人材の育成を支援
# Link: https://www.lycorp.co.jp/ja/news/release/017527/
# --------------------
# Date: 2025年4月24日
# Title: Yahoo!検索、生成AIを活用して都道府県別のおすすめ料理や名物などのグルメ情報を表示する機能を提供開始
