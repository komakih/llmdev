# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())

# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())
# Out:
# {'_request_id': 'req_091b8cf33e2128d1155d04c78770047b',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使用する際のポイントはいくつかあります。以下に主なポイントを挙げます：\n\n1. **目的を明確にする**: 言語モデルを使用する目的を明確にし、その目的に応じた適切なモデルや設定を選ぶことが重要です。\n\n2. **入力の質**: モデルに与える入力（プロンプト）は、結果に大きな影響を与えます。具体的で明確な指示を与えることで、より良い出力が得られる可能性が高まります。\n\n3. **文脈を考慮する**: 言語モデルは文脈に依存します。関連する情報や背景を適切に提供することで、より適切な応答を引き出すことができます。\n\n4. **フィードバックループの活用**: 出力が期待通りでない場合、プロンプトを調整したり、フィードバックを活用して改善に努めることが重要です。\n\n5. **倫理的考慮**: 言語モデルは偏見を持つ可能性があるため、出力に対して批判的な視点を持ち、倫理的な配慮を忘れないようにしましょう。\n\n6. **知識の限界**: モデルはトレーニングデータに基づいて回答を生成しますが、最新の情報や具体的なデータについては正確でない場合があります。信頼できる情報源を確認することが重要です。\n\n7. **セキュリティとプライバシー**: 個人情報や機密情報をモデルに入力しないように気を付けることが必要です。プライバシー保護を意識しましょう。\n\nこれらのポイントを考慮することで、言語モデルの活用がより効果的になるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1747111920,
#  'id': 'chatcmpl-BWbuSzPsk87VLaBHcJpJDoty7JdJ0',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_96c46af214',
#  'usage': CompletionUsage(completion_tokens=432, prompt_tokens=18, total_tokens=450, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを使用する際のポイントはいくつかあります。以下に主なポイントを挙げます：
#
# 1. **目的を明確にする**: 言語モデルを使用する目的を明確にし、その目的に応じた適切なモデルや設定を選ぶことが重要です。
#
# 2. **入力の質**: モデルに与える入力（プロンプト）は、結果に大きな影響を与えます。具体的で明確な指示を与えることで、より良い出力が得られる可能性が高まります。
#
# 3. **文脈を考慮する**: 言語モデルは文脈に依存します。関連する情報や背景を適切に提供することで、より適切な応答を引き出すことができます。
#
# 4. **フィードバックループの活用**: 出力が期待通りでない場合、プロンプトを調整したり、フィードバックを活用して改善に努めることが重要です。
#
# 5. **倫理的考慮**: 言語モデルは偏見を持つ可能性があるため、出力に対して批判的な視点を持ち、倫理的な配慮を忘れないようにしましょう。
#
# 6. **知識の限界**: モデルはトレーニングデータに基づいて回答を生成しますが、最新の情報や具体的なデータについては正確でない場合があります。信頼できる情報源を確認することが重要です。
#
# 7. **セキュリティとプライバシー**: 個人情報や機密情報をモデルに入力しないように気を付けることが必要です。プライバシー保護を意識しましょう。
#
# これらのポイントを考慮することで、言語モデルの活用がより効果的になるでしょう。
# 新製品の発売に向けた効果的なマーケティング戦略を立てるためには、以下のステップを実施することが重要です。
#
# ### 1. 市場調査の実施
# - **ターゲット市場の特定**: 新製品がどの顧客層に向けられているのかを明確にします。年齢、性別、趣味、ライフスタイルなどを考慮します。
# - **競合分析**: 競合他社の製品や戦略を分析し、自社製品のユニークなセールスポイント（USP）を明確にします。
#
# ### 2. 製品のポジショニング
# - **ブランドストーリーの構築**: 新製品がどのような価値を提供し、どのような問題を解決するのかを明確にします。また、ブランドの理念や感情に訴えるストーリーを構築します。
# - **価格戦略の設定**: 競合と比較した際の価格の位置づけや、ディスカウント戦略などを考慮します。
#
# ### 3. マーケティングチャネルの選定
# - **デジタルマーケティング**: SNS広告、Google広告、インフルエンサーとのコラボレーションなどを活用して、オンラインでのプレゼンスを強化します。
# - **オフラインチャネル**: イベント、展示会、ポップアップショップなどのリアルなアプローチを考えます。
#
# ### 4. コンテンツマーケティングの展開
# - **教育コンテンツやウェビナー**: 製品の使い方や利点を解説したコンテンツを作成します。これにより、顧客に対して製品の理解を深めてもらいます。
# - **SEO対策**: 製品関連のキーワードを調査し、ブログ記事やウェブページを最適化します。
#
# ### 5. プリローンチ活動
# - **ティーザーキャンペーン**: 発売前に製品の一部を公開して関心を高め、期待感を醸成します。
# - **メールリストの構築**: 興味を持っている顧客のリストを作成し、発売日に向けた情報を配信します。
#
# ### 6. ローンチイベントの実施
# - **製品発表会**: 新製品の特長を強調する記者会見やオンライン発表会を開催し、メディアや重要なステークホルダーを招待します。
# - **特別オファー**: 発売日に合わせて特別価格や購入特典を提供して、顧客の購入意欲を促進します。
#
# ### 7. フィードバックと改善
# - **顧客フィードバックの収集**: 製品発売後、顧客からのフィードバックを収集し、製品やサービスの改善に活かします。
# - **データ分析**: 販売データやマーケティングキャンペーンの効果を分析し、次回の戦略に反映させます。
#
# これらの施策を組み合わせることで、新製品の効果的なマーケティング戦略を構築し、成功へと導くことができます。

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=0.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、地域の文化や歴史を感じることができます。
# - **茶道**:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、色鮮やかで活気に満ちています。
# - **茶道**:
# --------------------
# もちろんです！日本は多様な文化、歴史、自然、美食などが魅力的な国です。以下にいくつかのポイントを紹介します。
#
# ### 1. 文化と伝統
# - **祭り**: 日本各地で行われる伝統的な祭り（例：祇園祭、ねぶた祭り）は、色鮮やかで活気に満ちています。
# - **茶道**:

# %%
# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    presence_penalty=-2.0,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# もちろんです！日本には多くの魅力がありますので、いくつかを紹介します。
#
# ### 1. 文化と伝統
# 日本は長い歴史と独自の文化を持つ国です。茶道、花道、書道などの伝統芸能や、祭りや神社、仏閣など、歴史を感じさせる場所が多く存在します。
#
# ### 2. 美しい自然
# 日本は
# --------------------
# 日本には多くの魅力がありますが、いくつかのポイントを紹介します。
#
# 1. **伝統文化**: 日本の伝統行事や文化は、茶道や華道、武道、祭りなど多岐にわたります。特に祭りは地域ごとに特色があり、訪れるたびに新しい発見があります。
#
# 2. **四季の美**: 日本は四季がはっきり
# --------------------
# もちろんです！日本の魅力は多岐にわたりますが、いくつかのポイントを挙げてみます。
#
# 1. **豊かな文化と歴史**: 日本は長い歴史を持つ国で、古代の神社やお寺、伝統的な町並みが多く残っています。京都や奈良での歴史的な観光地は特に有名です。
#
# 2. **美

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=2
# tokens=[95839, 3393]

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {95839:8, 3393:8}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B:こんにちは！Aさん、元気ですか？
# --------------------
# B:こんにちは！Aさん、最近どうですか？
# --------------------
# B:こんにちは！Aさん、元気にしてた？

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを効果的に使用するためのポイントはいくつかあります。以下に主なものを挙げます。
#
# 1. **明確なプロンプトの作成**: モデルに対する入力（プロンプト）は明確で具体的な内容にすることが重要です。そうすることで、望むアウトプットが得やすくなります。
#
# 2. **コンテキストの提供**: モデルが理解しやすいように、必要な背景情報やコンテキストを提供することで、より適切な応答を引き出すことができます。
#
# 3. **反復と洗練**: 最初の回答が期待外れの場合もあるため、プロンプトを何度も修正・反復しながら、求める情報やスタイルに近づけていくことが重要です。
#
# 4. **トーンの指定**: 応答のスタイルやトーンを指定することで、より適した表現を得ることができます。例えば、「カジュアルに答えてください」や「フォーマルにお願いします」といった指示が有効です。
#
# 5. **フィードバックの活用**: 取得した結果に対してフィードバックを与えたり、間違いや不足を指摘することで、より良い結果を引き出すためのプロンプトを洗練させることができます。
#
# 6. **適切な制限を設ける**: モデルには場合によっては制約を設けることも有効です。例えば、文字数やトピックの範囲を制限すると、より焦点が絞られた応答が得られやすくなります。
#
# 7. **安全性と倫理を考慮する**: モデルの使用にあたっては、データの使用に関する倫理やプライバシー、安全性に配慮し、適切な使用方法を心掛けることが重要です。
#
# 8. **多様な視点の考慮**: モデルが生成する情報は多様であるため、異なる視点を取り入れることが重要です。一つの意見に偏らず、複数の観点を考慮することが推奨されます。
#
# これらのポイントを意識して使用することで、言語モデルからより良い結果を引き出すことができるでしょう。

# %%
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

# %%
for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 言語モデルを使用する際のポイントはいくつかあります。以下に挙げるのは、その主な注意点や活用方法です。
#
# 1. **目的を明確にする**: 言語モデルを使用する目的を明確にすることが重要です。テキスト生成、要約、翻訳、質問応答など、実現したいことを具体的に定めましょう。
#
# 2. **入力の質を考える**: モデルに与える入力（プロンプト）の質が結果に大きく影響します。具体的で明確な指示や文脈を提供することで、より良い結果が得られます。
#
# 3. **出力の評価**: モデルからの出力は必ずしも正確または信頼できるとは限りません。結果を評価・検証し、必要に応じて手動で修正することが重要です。
#
# 4. **意図しないバイアスに注意**: AIモデルは学習データに基づいており、そのデータにバイアスが含まれている可能性があります。出力には無意識的な偏見が反映されることがあるため、注意が必要です。
#
# 5. **反復的なプロセス**: 最初の試行で満足のいく結果が得られないことが多いです。何度も試行錯誤を重ね、プロンプトや条件を調整することで、より良い出力を得ることができます。
#
# 6. **ユーザーのニーズに応じたカスタマイズ**: 特定の産業や用途に応じてモデルを微調整することが可能な場合もあります。これにより、ユーザーのニーズにより適した結果を得ることができます。
#
# 7. **プライバシーとセキュリティ**: 特に敏感な情報を扱う際は、プライバシーとデータ保護に注意を払う必要があります。個人情報を含むデータをモデルに入力することは避けるべきです。
#
# 8. **適切なツールやライブラリを選択**: 使用する言語モデルやAPIの選択も重要です。それぞれのモデルには特徴や利点があるため、目的に合ったものを選びましょう。
#
# これらのポイントを考慮に入れながら、言語モデルを効果的に活用することができるでしょう。
